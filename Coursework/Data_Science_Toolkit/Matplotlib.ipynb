# %% [markdown]
# # Matplotlib for Machine Learning & Data Science Students
#
# A practical, student-friendly notebook covering the most useful **Matplotlib** commands for data analysis, ML, and model evaluation.
#
# ## Learning path
# **Figure → Axes → Basic plots → Customization → Multiple plots → Statistical plots → ML visualizations → Model evaluation → Save figures**
#
# Matplotlib is the foundation behind many Python visualization libraries.

# %%
pip install matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 337.8 kB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.0/125.0 kB 699.5 kB/s eta 0:00:00a 0:00:01
# ...
#   Using cached pillow-12.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 3.3 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.2/383.2 kB 1.2 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 987.3 kB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 1.0 MB/s eta 0:00:0000:0100:010m
# Using cached pillow-12.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.9 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.4/126.4 kB 1.2 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Install if needed:
# !pip install matplotlib pandas numpy scikit-learn

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("Matplotlib version:", plt.matplotlib.__version__)
# Out:
# Matplotlib version: 3.11.2

# %% [markdown]
# ## 1. Basic Line Plot
#
# A line plot is useful for trends over time or ordered observations.

# %%
x = [1, 2, 3, 4, 5]
y = [10, 15, 13, 20, 25]

plt.plot(x, y)
plt.show()

# %% [markdown]
# ## 2. Add Title, Labels and Grid

# %%
plt.plot(x, y)

plt.title("Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.grid(True)

plt.show()

# %% [markdown]
# ## 3. Line Styles and Markers

# %%
plt.plot(
    x, y,
    marker="o",
    linestyle="--",
    linewidth=2,
    label="Sales"
)

plt.title("Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 4. Multiple Lines

# %%
months = [1, 2, 3, 4, 5]
sales_a = [10, 15, 13, 20, 25]
sales_b = [8, 12, 16, 18, 23]

plt.plot(months, sales_a, marker="^", label="Product A")
plt.plot(months, sales_b, marker="s", label="Product B")

plt.title("Product Sales Comparison")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 5. Bar Chart
#
# Bar charts are useful for comparing categories.

# %%
departments = ["IT", "HR", "Finance", "Sales"]
employees = [40, 20, 25, 35]

plt.bar(departments, employees)

plt.title("Employees by Department")
plt.xlabel("Department")
plt.ylabel("Employees")
plt.show()

# %% [markdown]
# ## 6. Horizontal Bar Chart

# %%
plt.barh(departments, employees)

plt.title("Employees by Department")
plt.xlabel("Employees")
plt.ylabel("Department")
plt.show()

# %% [markdown]
# ## 7. Grouped Bar Chart

# %%
departments = ["IT", "HR", "Finance"]
male = [25, 10, 15]
female = [15, 20, 10]

pos = np.arange(len(departments))
width = 0.35

plt.bar(pos - width/2, male, width, label="Male")
plt.bar(pos + width/2, female, width, label="Female")

plt.xticks(pos, departments)
plt.ylabel("Employees")
plt.title("Employees by Department and Gender")
plt.legend()
plt.show()

# %% [markdown]
# ## 8. Scatter Plot
#
# Scatter plots are useful for studying relationships between two numerical variables.

# %%
age = np.array([20, 22, 25, 28, 30, 35, 40, 45])
salary = np.array([35, 38, 45, 50, 55, 65, 75, 90])

plt.scatter(age, salary)

plt.title("Age vs Salary")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.grid(True)
plt.show()

# %% [markdown]
# ## 9. Histogram
#
# Histograms show the distribution of a numerical variable.

# %%
rng = np.random.default_rng(42)
salary = rng.normal(60000, 12000, 500)

plt.hist(salary, bins=20)

plt.title("Salary Distribution")
plt.xlabel("Salary")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## 10. Histogram Density

# %%
plt.hist(salary, bins=20, density=True)

plt.title("Salary Distribution Density")
plt.xlabel("Salary")
plt.ylabel("Density")
plt.show()

# %% [markdown]
# ## 11. Box Plot
#
# Box plots help identify median, spread, and potential outliers.

# %%
data = [45, 50, 52, 55, 58, 60, 62, 65, 100]

plt.boxplot(data)

plt.title("Box Plot")
plt.ylabel("Value")
plt.show()

# %% [markdown]
# ## 12. Pie Chart
#
# Pie charts can show simple proportions. For many categories, bar charts are often easier to read.

# %%
labels = ["IT", "HR", "Finance", "Sales"]
values = [40, 20, 25, 35]

plt.pie(
    values,
    labels=labels,
    autopct="%1.1f%%"
)

plt.title("Department Distribution")
plt.show()

# %% [markdown]
# ## 13. Figure and Axes
#
# The object-oriented Matplotlib style is important for professional ML/data-science visualizations.
#
# - `fig` = complete figure
# - `ax` = individual plotting area

# %%
fig, ax = plt.subplots()

ax.plot(x, y, marker="o")
ax.set_title("Sales")
ax.set_xlabel("Month")
ax.set_ylabel("Sales")
ax.grid(True)

plt.show()

# %% [markdown]
# ## 14. Subplots

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

axes[0].plot(x, y, marker="o")
axes[0].set_title("Line Plot")

bar_departments = ["IT", "HR", "Finance", "Sales"]
bar_employees = [40, 20, 25, 35]
axes[1].bar(bar_departments, bar_employees)
axes[1].set_title("Bar Plot")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 15. 2 × 2 Subplots

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

axes[0, 0].plot(x, y)
axes[0, 0].set_title("Line")

bar_departments = ["IT", "HR", "Finance", "Sales"]
bar_employees = [40, 20, 25, 35]
axes[0, 1].bar(bar_departments, bar_employees)
axes[0, 1].set_title("Bar")

scatter_age = np.array([20, 22, 25, 28, 30, 35, 40, 45])
scatter_salary = np.array([35, 38, 45, 50, 55, 65, 75, 90])
axes[1, 0].scatter(scatter_age, scatter_salary)
axes[1, 0].set_title("Scatter")

axes[1, 1].hist(salary, bins=15)
axes[1, 1].set_title("Histogram")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 16. Annotating a Point

# %%
x = np.array([1,2,3,4,5])
y = np.array([10,15,13,20,25])

plt.plot(x, y, marker="o")

plt.annotate(
    "Highest",
    xy=(5, 25),
    xytext=(3.5, 22),
    arrowprops={"arrowstyle": "->"}
)

plt.show()

# %% [markdown]
# ## 17. Axis Limits

# %%
plt.plot(x, y)

plt.xlim(1, 5)
plt.ylim(0, 30)

plt.title("Controlled Axis Range")
plt.show()

# %% [markdown]
# ## 18. Twin Y-Axis
#
# Useful when two variables have very different scales.

# %%
months = np.arange(1, 7)
sales = [20, 25, 30, 35, 40, 45]
profit = [2, 3, 4, 5, 6, 8]

fig, ax1 = plt.subplots()

ax1.plot(months, sales, marker="o")
ax1.set_xlabel("Month")
ax1.set_ylabel("Sales")

ax2 = ax1.twinx()
ax2.plot(months, profit, marker="s", linestyle="--")
ax2.set_ylabel("Profit")

plt.title("Sales and Profit")
plt.show()

# %% [markdown]
# ## 19. Correlation Heatmap with Matplotlib
#
# A heatmap can be created directly with `imshow()`.

# %%
data = np.array([
    [1.0, 0.8, 0.2],
    [0.8, 1.0, 0.4],
    [0.2, 0.4, 1.0]
])

plt.imshow(data, aspect="auto")
plt.colorbar()

plt.xticks(range(3), ["Age", "Salary", "Experience"])
plt.yticks(range(3), ["Age", "Salary", "Experience"])

plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# ## 20. ML: Actual vs Predicted

# %%
actual = np.array([100, 120, 130, 150, 170])
predicted = np.array([105, 115, 128, 145, 175])

plt.scatter(actual, predicted)

# Ideal prediction line
minimum = min(actual.min(), predicted.min())
maximum = max(actual.max(), predicted.max())

plt.plot([minimum, maximum], [minimum, maximum], linestyle="--")

plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")
plt.grid(True)
plt.show()

# %% [markdown]
# ## 21. ML: Residual Plot
#
# Residual = Actual − Predicted

# %%
residuals = actual - predicted

plt.scatter(predicted, residuals)
plt.axhline(0, linestyle="--")

plt.xlabel("Predicted")
plt.ylabel("Residual")
plt.title("Residual Plot")
plt.grid(True)
plt.show()

# %% [markdown]
# ## 22. ML: Confusion Matrix Visualization

# %%
from sklearn.metrics import confusion_matrix

y_true = [0, 0, 0, 1, 1, 1, 1, 0]
y_pred = [0, 1, 0, 1, 1, 0, 1, 0]

cm = confusion_matrix(y_true, y_pred)

plt.imshow(cm)
plt.colorbar()

plt.xticks([0, 1], ["Pred 0", "Pred 1"])
plt.yticks([0, 1], ["Actual 0", "Actual 1"])

for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        plt.text(j, i, cm[i, j], ha="center", va="center")

plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# ## 23. ML: Training Loss Curve

# %%
epochs = np.arange(1, 11)
train_loss = [0.90, 0.70, 0.55, 0.45, 0.37, 0.31, 0.27, 0.24, 0.22, 0.20]
val_loss = [0.95, 0.76, 0.62, 0.54, 0.49, 0.47, 0.48, 0.50, 0.53, 0.56]

plt.plot(epochs, train_loss, marker="o", label="Training Loss")
plt.plot(epochs, val_loss, marker="s", label="Validation Loss")

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 24. Feature Importance

# %%
features = ["Age", "Income", "Experience", "Education"]
importance = [0.15, 0.45, 0.30, 0.10]

plt.barh(features, importance)

plt.xlabel("Importance")
plt.title("Feature Importance")
plt.show()

# %% [markdown]
# ## 25. Save a Figure

# %%
save_x = [1, 2, 3, 4, 5]
save_y = [10, 15, 13, 20, 25]

plt.plot(save_x, save_y, marker="o")
plt.title("Sales Trend")

# Save as PNG
plt.savefig("sales_trend.png", dpi=300, bbox_inches="tight")

plt.show()

# %% [markdown]
# ## 26. Style Basics
#
# Matplotlib can be configured with labels, legends, grids, markers, line styles, figure size, and transparency.
#
# For teaching, focus first on understanding the data and the correct chart type rather than decorative styling.

# %%
style_x = [1, 2, 3, 4, 5]
style_y = [10, 15, 13, 20, 25]

fig, ax = plt.subplots(figsize=(8, 5))

ax.plot(
    style_x, style_y,
    marker="o",
    linewidth=2,
    alpha=0.8,
    label="Sales"
)

ax.set_title("Professional-Style Sales Plot")
ax.set_xlabel("Month")
ax.set_ylabel("Sales")
ax.legend()
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Matplotlib Quick Reference
#
# | Purpose | Command |
# |---|---|
# | Line | `plt.plot()` |
# | Bar | `plt.bar()` |
# | Horizontal bar | `plt.barh()` |
# | Scatter | `plt.scatter()` |
# | Histogram | `plt.hist()` |
# | Box plot | `plt.boxplot()` |
# | Pie | `plt.pie()` |
# | Figure | `plt.figure()` |
# | Subplots | `plt.subplots()` |
# | Title | `plt.title()` / `ax.set_title()` |
# | X label | `plt.xlabel()` / `ax.set_xlabel()` |
# | Y label | `plt.ylabel()` / `ax.set_ylabel()` |
# | Legend | `plt.legend()` / `ax.legend()` |
# | Grid | `plt.grid()` / `ax.grid()` |
# | Limits | `plt.xlim()`, `plt.ylim()` |
# | Annotation | `plt.annotate()` |
# | Save | `plt.savefig()` |
# | Show | `plt.show()` |
#
# ## ML visualization mental model
#
# `Data → Explore → Plot Distributions → Plot Relationships → Evaluate Model → Plot Errors → Communicate Results`

# %% [markdown]
# # Exercises
#
# ### Exercise 1
# Create a line chart for monthly sales.
#
# ### Exercise 2
# Create a histogram of student marks.
#
# ### Exercise 3
# Create a scatter plot of study hours vs marks.
#
# ### Exercise 4
# Create a box plot and identify potential outliers.
#
# ### Exercise 5
# Plot actual vs predicted house prices.
#
# ### Exercise 6
# Create training and validation loss curves.
#
# ### Exercise 7
# Visualize a 3×3 confusion matrix and add the values inside each cell.
